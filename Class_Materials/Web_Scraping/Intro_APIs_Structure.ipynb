# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '28671091883',
#   'type': 'PushEvent',
#   'actor': {'id': 124123424,
#    'login': 'AerixTenderly',
#    'display_login': 'AerixTenderly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AerixTenderly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124123424?'},
#   'repo': {'id': 604025236,
#    'name': 'AerixTenderly/csv_test',
#    'url': 'https://api.github.com/repos/AerixTenderly/csv_test'},
#   'payload': {'repository_id': 604025236,
#    'push_id': 13430594671,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '45ccfe3c1a2176b30c182ed04cd6b2dc0f4153c7',
#    'before': '592ad3213a68e6ec00e88526313dd855e8930612',
#    'commits': [{'sha': '45ccfe3c1a2176b30c182ed04cd6b2dc0f4153c7',
#      'author': {'email': '124123424+AerixTenderly@users.noreply.github.com',
#       'name': 'AerixTenderly'},
#      'message': 'commit message',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AerixTenderly/csv_test/commits/45ccfe3c1a2176b30c182ed04cd6b2dc0f4153c7'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091860',
#   'type': 'PushEvent',
#   'actor': {'id': 77650507,
#    'login': 'abduljwadhigaig',
#    'display_login': 'abduljwadhigaig',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abduljwadhigaig',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77650507?'},
#   'repo': {'id': 619903340,
#    'name': 'abduljwadhigaig/Network-configuration-automation',
#    'url': 'https://api.github.com/repos/abduljwadhigaig/Network-configuration-automation'},
#   'payload': {'repository_id': 619903340,
#    'push_id': 13430594679,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1bff598ac2cddde280edfe3a1e7fb55cfa6e3783',
#    'before': 'c54928bc2d62061a6949583a808edf4215ade457',
#    'commits': [{'sha': '1bff598ac2cddde280edfe3a1e7fb55cfa6e3783',
#      'author': {'email': '77650507+abduljwadhigaig@users.noreply.github.com',
#       'name': 'Abduljwad Higaig'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/abduljwadhigaig/Network-configuration-automation/commits/1bff598ac2cddde280edfe3a1e7fb55cfa6e3783'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091889',
#   'type': 'GollumEvent',
#   'actor': {'id': 3818079,
#    'login': 'StevenMaude',
#    'display_login': 'StevenMaude',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/StevenMaude',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3818079?'},
#   'repo': {'id': 379919397,
#    'name': 'opensafely-core/ehrql',
#    'url': 'https://api.github.com/repos/opensafely-core/ehrql'},
#   'payload': {'pages': [{'page_name': 'ehrQL-examples',
#      'title': 'ehrQL examples',
#      'summary': None,
#      'action': 'edited',
#      'sha': 'ee5cef0259e872877d24185bac0348a2e566abbc',
#      'html_url': 'https://github.com/opensafely-core/ehrql/wiki/ehrQL-examples'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z',
#   'org': {'id': 77844139,
#    'login': 'opensafely-core',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/opensafely-core',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77844139?'}},
#  {'id': '28671091876',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 113453627,
#    'login': 'Akshay-Durgade',
#    'display_login': 'Akshay-Durgade',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Akshay-Durgade',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/113453627?'},
#   'repo': {'id': 632855172,
#    'name': 'Akshay-Durgade/mindstixprac',
#    'url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/1',
#     'id': 1328433520,
#     'node_id': 'PR_kwDOJbiahM5PLklw',
#     'html_url': 'https://github.com/Akshay-Durgade/mindstixprac/pull/1',
#     'diff_url': 'https://github.com/Akshay-Durgade/mindstixprac/pull/1.diff',
#     'patch_url': 'https://github.com/Akshay-Durgade/mindstixprac/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'gitesh first commit',
#     'user': {'login': 'Akshay-Durgade',
#      'id': 113453627,
#      'node_id': 'U_kgDOBsMqOw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/113453627?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Akshay-Durgade',
#      'html_url': 'https://github.com/Akshay-Durgade',
#      'followers_url': 'https://api.github.com/users/Akshay-Durgade/followers',
#      'following_url': 'https://api.github.com/users/Akshay-Durgade/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Akshay-Durgade/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Akshay-Durgade/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Akshay-Durgade/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Akshay-Durgade/orgs',
#      'repos_url': 'https://api.github.com/users/Akshay-Durgade/repos',
#      'events_url': 'https://api.github.com/users/Akshay-Durgade/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Akshay-Durgade/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-04-26T09:31:43Z',
#     'updated_at': '2023-04-26T09:31:43Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/statuses/d9a7cd7f2da1d6e0d8a8526033357f7c38ea3d40',
#     'head': {'label': 'Akshay-Durgade:dev',
#      'ref': 'dev',
#      'sha': 'd9a7cd7f2da1d6e0d8a8526033357f7c38ea3d40',
#      'user': {'login': 'Akshay-Durgade',
#       'id': 113453627,
#       'node_id': 'U_kgDOBsMqOw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/113453627?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Akshay-Durgade',
#       'html_url': 'https://github.com/Akshay-Durgade',
#       'followers_url': 'https://api.github.com/users/Akshay-Durgade/followers',
#       'following_url': 'https://api.github.com/users/Akshay-Durgade/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Akshay-Durgade/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Akshay-Durgade/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Akshay-Durgade/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Akshay-Durgade/orgs',
#       'repos_url': 'https://api.github.com/users/Akshay-Durgade/repos',
#       'events_url': 'https://api.github.com/users/Akshay-Durgade/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Akshay-Durgade/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 632855172,
#       'node_id': 'R_kgDOJbiahA',
#       'name': 'mindstixprac',
#       'full_name': 'Akshay-Durgade/mindstixprac',
#       'private': False,
#       'owner': {'login': 'Akshay-Durgade',
#        'id': 113453627,
#        'node_id': 'U_kgDOBsMqOw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/113453627?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Akshay-Durgade',
#        'html_url': 'https://github.com/Akshay-Durgade',
#        'followers_url': 'https://api.github.com/users/Akshay-Durgade/followers',
#        'following_url': 'https://api.github.com/users/Akshay-Durgade/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Akshay-Durgade/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Akshay-Durgade/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Akshay-Durgade/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Akshay-Durgade/orgs',
#        'repos_url': 'https://api.github.com/users/Akshay-Durgade/repos',
#        'events_url': 'https://api.github.com/users/Akshay-Durgade/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Akshay-Durgade/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Akshay-Durgade/mindstixprac',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac',
#       'forks_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/forks',
#       'keys_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/teams',
#       'hooks_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/events',
#       'assignees_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/tags',
#       'blobs_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/languages',
#       'stargazers_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/subscription',
#       'commits_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/merges',
#       'archive_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/downloads',
#       'issues_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/deployments',
#       'created_at': '2023-04-26T09:13:38Z',
#       'updated_at': '2023-04-26T09:19:30Z',
#       'pushed_at': '2023-04-26T09:31:43Z',
#       'git_url': 'git://github.com/Akshay-Durgade/mindstixprac.git',
#       'ssh_url': 'git@github.com:Akshay-Durgade/mindstixprac.git',
#       'clone_url': 'https://github.com/Akshay-Durgade/mindstixprac.git',
#       'svn_url': 'https://github.com/Akshay-Durgade/mindstixprac',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'Akshay-Durgade:main',
#      'ref': 'main',
#      'sha': '57f8ed141ca5d0ee08ad153094c9fed5b6afcdde',
#      'user': {'login': 'Akshay-Durgade',
#       'id': 113453627,
#       'node_id': 'U_kgDOBsMqOw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/113453627?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Akshay-Durgade',
#       'html_url': 'https://github.com/Akshay-Durgade',
#       'followers_url': 'https://api.github.com/users/Akshay-Durgade/followers',
#       'following_url': 'https://api.github.com/users/Akshay-Durgade/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Akshay-Durgade/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Akshay-Durgade/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Akshay-Durgade/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Akshay-Durgade/orgs',
#       'repos_url': 'https://api.github.com/users/Akshay-Durgade/repos',
#       'events_url': 'https://api.github.com/users/Akshay-Durgade/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Akshay-Durgade/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 632855172,
#       'node_id': 'R_kgDOJbiahA',
#       'name': 'mindstixprac',
#       'full_name': 'Akshay-Durgade/mindstixprac',
#       'private': False,
#       'owner': {'login': 'Akshay-Durgade',
#        'id': 113453627,
#        'node_id': 'U_kgDOBsMqOw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/113453627?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Akshay-Durgade',
#        'html_url': 'https://github.com/Akshay-Durgade',
#        'followers_url': 'https://api.github.com/users/Akshay-Durgade/followers',
#        'following_url': 'https://api.github.com/users/Akshay-Durgade/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Akshay-Durgade/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Akshay-Durgade/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Akshay-Durgade/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Akshay-Durgade/orgs',
#        'repos_url': 'https://api.github.com/users/Akshay-Durgade/repos',
#        'events_url': 'https://api.github.com/users/Akshay-Durgade/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Akshay-Durgade/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Akshay-Durgade/mindstixprac',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac',
#       'forks_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/forks',
#       'keys_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/teams',
#       'hooks_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/events',
#       'assignees_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/tags',
#       'blobs_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/languages',
#       'stargazers_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/subscription',
#       'commits_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/merges',
#       'archive_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/downloads',
#       'issues_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/deployments',
#       'created_at': '2023-04-26T09:13:38Z',
#       'updated_at': '2023-04-26T09:19:30Z',
#       'pushed_at': '2023-04-26T09:31:43Z',
#       'git_url': 'git://github.com/Akshay-Durgade/mindstixprac.git',
#       'ssh_url': 'git@github.com:Akshay-Durgade/mindstixprac.git',
#       'clone_url': 'https://github.com/Akshay-Durgade/mindstixprac.git',
#       'svn_url': 'https://github.com/Akshay-Durgade/mindstixprac',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/1'},
#      'html': {'href': 'https://github.com/Akshay-Durgade/mindstixprac/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Akshay-Durgade/mindstixprac/statuses/d9a7cd7f2da1d6e0d8a8526033357f7c38ea3d40'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091867',
#   'type': 'PushEvent',
#   'actor': {'id': 13675568,
#    'login': 'cottinisimone',
#    'display_login': 'cottinisimone',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cottinisimone',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13675568?'},
#   'repo': {'id': 342593181,
#    'name': 'primait/event_sourcing.rs',
#    'url': 'https://api.github.com/repos/primait/event_sourcing.rs'},
#   'payload': {'repository_id': 342593181,
#    'push_id': 13430594676,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/PLATFORM-1073/task/streamline-projectors-and-policies',
#    'head': '170d68b81ba9927d631c87d1768576e5b6f02f80',
#    'before': '31fb036dd88aae81094eb8378fdb1f8a9db1592d',
#    'commits': [{'sha': '170d68b81ba9927d631c87d1768576e5b6f02f80',
#      'author': {'email': 'cottini.simone@gmail.com', 'name': 'Simone Cottini'},
#      'message': 'Fix rebuild strategies example (still in WIP)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/primait/event_sourcing.rs/commits/170d68b81ba9927d631c87d1768576e5b6f02f80'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z',
#   'org': {'id': 6067435,
#    'login': 'primait',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/primait',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6067435?'}},
#  {'id': '28671091868',
#   'type': 'DeleteEvent',
#   'actor': {'id': 84911237,
#    'login': 'clementvtrd',
#    'display_login': 'clementvtrd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clementvtrd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84911237?'},
#   'repo': {'id': 521348557,
#    'name': 'clementvtrd/boilerplate-graphql',
#    'url': 'https://api.github.com/repos/clementvtrd/boilerplate-graphql'},
#   'payload': {'ref': 'feature/gh-pages',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091854',
#   'type': 'WatchEvent',
#   'actor': {'id': 77135122,
#    'login': 'quanlijie',
#    'display_login': 'quanlijie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/quanlijie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77135122?'},
#   'repo': {'id': 579082810,
#    'name': 'dair-ai/Prompt-Engineering-Guide',
#    'url': 'https://api.github.com/repos/dair-ai/Prompt-Engineering-Guide'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z',
#   'org': {'id': 30384625,
#    'login': 'dair-ai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dair-ai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30384625?'}},
#  {'id': '28671091837',
#   'type': 'PushEvent',
#   'actor': {'id': 71933125,
#    'login': 'moha-mame',
#    'display_login': 'moha-mame',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moha-mame',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71933125?'},
#   'repo': {'id': 615183198,
#    'name': 'moha-mame/AirBnB_clone_v2',
#    'url': 'https://api.github.com/repos/moha-mame/AirBnB_clone_v2'},
#   'payload': {'repository_id': 615183198,
#    'push_id': 13430594668,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3bca6599b06abc385242c9db8b267e3add87b140',
#    'before': 'e38192d504d8e3af74baecc9055c98a0f2f4b4d7',
#    'commits': [{'sha': '3bca6599b06abc385242c9db8b267e3add87b140',
#      'author': {'email': '', 'name': 'moha-mame'},
#      'message': 'web_flask',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/moha-mame/AirBnB_clone_v2/commits/3bca6599b06abc385242c9db8b267e3add87b140'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091841',
#   'type': 'PushEvent',
#   'actor': {'id': 69181112,
#    'login': 'hoangdinhphong',
#    'display_login': 'hoangdinhphong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hoangdinhphong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69181112?'},
#   'repo': {'id': 284864670,
#    'name': 'hoangdinhphong/hoangdinhphong.github.io',
#    'url': 'https://api.github.com/repos/hoangdinhphong/hoangdinhphong.github.io'},
#   'payload': {'repository_id': 284864670,
#    'push_id': 13430594659,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '23045d44dacb43f6c20ef3200136a2b9d2a6f4f9',
#    'before': '197c166ff34de127942155fde31690e642689373',
#    'commits': [{'sha': '23045d44dacb43f6c20ef3200136a2b9d2a6f4f9',
#      'author': {'email': 'tuananh88.bichphuong93@gmail.com',
#       'name': 'tuananh-sonla'},
#      'message': '-',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hoangdinhphong/hoangdinhphong.github.io/commits/23045d44dacb43f6c20ef3200136a2b9d2a6f4f9'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091787',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 505266582,
#    'name': 'kherrick/slashdot',
#    'url': 'https://api.github.com/repos/kherrick/slashdot'},
#   'payload': {'repository_id': 505266582,
#    'push_id': 13430594638,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'fe35ed94ef50218c47d3c1865f9d5cf818cee39b',
#    'before': '5dfaee1a2b6fe140a6fe5fbe89e59b802515ff27',
#    'commits': [{'sha': 'fe35ed94ef50218c47d3c1865f9d5cf818cee39b',
#      'author': {'email': 'me@karlherrick.com', 'name': 'Karl Herrick'},
#      'message': 'Build gh-pages: Wed Apr 26 09:31:42 UTC 2023',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kherrick/slashdot/commits/fe35ed94ef50218c47d3c1865f9d5cf818cee39b'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091792',
#   'type': 'CreateEvent',
#   'actor': {'id': 62055599,
#    'login': 'forzajuve99',
#    'display_login': 'forzajuve99',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/forzajuve99',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62055599?'},
#   'repo': {'id': 632862347,
#    'name': 'forzajuve99/Algoritmi2',
#    'url': 'https://api.github.com/repos/forzajuve99/Algoritmi2'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091765',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 117505462,
#    'login': 'Brijeshid',
#    'display_login': 'Brijeshid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Brijeshid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117505462?'},
#   'repo': {'id': 594708182,
#    'name': 'Brijeshid/gamesjunglee',
#    'url': 'https://api.github.com/repos/Brijeshid/gamesjunglee'},
#   'payload': {'action': 'closed',
#    'number': 21,
#    'pull_request': {'url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/21',
#     'id': 1328433311,
#     'node_id': 'PR_kwDOI3KG1s5PLkif',
#     'html_url': 'https://github.com/Brijeshid/gamesjunglee/pull/21',
#     'diff_url': 'https://github.com/Brijeshid/gamesjunglee/pull/21.diff',
#     'patch_url': 'https://github.com/Brijeshid/gamesjunglee/pull/21.patch',
#     'issue_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/21',
#     'number': 21,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Saurabh dev',
#     'user': {'login': 'Brijeshid',
#      'id': 117505462,
#      'node_id': 'U_kgDOBwD9tg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/117505462?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Brijeshid',
#      'html_url': 'https://github.com/Brijeshid',
#      'followers_url': 'https://api.github.com/users/Brijeshid/followers',
#      'following_url': 'https://api.github.com/users/Brijeshid/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Brijeshid/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Brijeshid/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Brijeshid/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Brijeshid/orgs',
#      'repos_url': 'https://api.github.com/users/Brijeshid/repos',
#      'events_url': 'https://api.github.com/users/Brijeshid/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Brijeshid/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-04-26T09:31:33Z',
#     'updated_at': '2023-04-26T09:31:42Z',
#     'closed_at': '2023-04-26T09:31:42Z',
#     'merged_at': '2023-04-26T09:31:42Z',
#     'merge_commit_sha': '88106f65821c3a716707db3ce2eefa0104e9da15',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/21/commits',
#     'review_comments_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/21/comments',
#     'review_comment_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/21/comments',
#     'statuses_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/statuses/46df39757fdc288624e69749377cde1577af27f3',
#     'head': {'label': 'Brijeshid:saurabh_dev',
#      'ref': 'saurabh_dev',
#      'sha': '46df39757fdc288624e69749377cde1577af27f3',
#      'user': {'login': 'Brijeshid',
#       'id': 117505462,
#       'node_id': 'U_kgDOBwD9tg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/117505462?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Brijeshid',
#       'html_url': 'https://github.com/Brijeshid',
#       'followers_url': 'https://api.github.com/users/Brijeshid/followers',
#       'following_url': 'https://api.github.com/users/Brijeshid/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Brijeshid/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Brijeshid/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Brijeshid/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Brijeshid/orgs',
#       'repos_url': 'https://api.github.com/users/Brijeshid/repos',
#       'events_url': 'https://api.github.com/users/Brijeshid/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Brijeshid/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 594708182,
#       'node_id': 'R_kgDOI3KG1g',
#       'name': 'gamesjunglee',
#       'full_name': 'Brijeshid/gamesjunglee',
#       'private': False,
#       'owner': {'login': 'Brijeshid',
#        'id': 117505462,
#        'node_id': 'U_kgDOBwD9tg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/117505462?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Brijeshid',
#        'html_url': 'https://github.com/Brijeshid',
#        'followers_url': 'https://api.github.com/users/Brijeshid/followers',
#        'following_url': 'https://api.github.com/users/Brijeshid/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Brijeshid/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Brijeshid/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Brijeshid/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Brijeshid/orgs',
#        'repos_url': 'https://api.github.com/users/Brijeshid/repos',
#        'events_url': 'https://api.github.com/users/Brijeshid/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Brijeshid/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Brijeshid/gamesjunglee',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Brijeshid/gamesjunglee',
#       'forks_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/forks',
#       'keys_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/teams',
#       'hooks_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/events',
#       'assignees_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/tags',
#       'blobs_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/languages',
#       'stargazers_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/subscription',
#       'commits_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/merges',
#       'archive_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/downloads',
#       'issues_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/deployments',
#       'created_at': '2023-01-29T11:59:02Z',
#       'updated_at': '2023-02-08T07:51:35Z',
#       'pushed_at': '2023-04-26T09:31:42Z',
#       'git_url': 'git://github.com/Brijeshid/gamesjunglee.git',
#       'ssh_url': 'git@github.com:Brijeshid/gamesjunglee.git',
#       'clone_url': 'https://github.com/Brijeshid/gamesjunglee.git',
#       'svn_url': 'https://github.com/Brijeshid/gamesjunglee',
#       'homepage': 'https://gamesjunglee-new.vercel.app',
#       'size': 5591,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'Brijeshid:main',
#      'ref': 'main',
#      'sha': '7ad317d8b35082f6cdf3842c85e5eebb24536fa7',
#      'user': {'login': 'Brijeshid',
#       'id': 117505462,
#       'node_id': 'U_kgDOBwD9tg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/117505462?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Brijeshid',
#       'html_url': 'https://github.com/Brijeshid',
#       'followers_url': 'https://api.github.com/users/Brijeshid/followers',
#       'following_url': 'https://api.github.com/users/Brijeshid/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Brijeshid/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Brijeshid/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Brijeshid/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Brijeshid/orgs',
#       'repos_url': 'https://api.github.com/users/Brijeshid/repos',
#       'events_url': 'https://api.github.com/users/Brijeshid/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Brijeshid/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 594708182,
#       'node_id': 'R_kgDOI3KG1g',
#       'name': 'gamesjunglee',
#       'full_name': 'Brijeshid/gamesjunglee',
#       'private': False,
#       'owner': {'login': 'Brijeshid',
#        'id': 117505462,
#        'node_id': 'U_kgDOBwD9tg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/117505462?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Brijeshid',
#        'html_url': 'https://github.com/Brijeshid',
#        'followers_url': 'https://api.github.com/users/Brijeshid/followers',
#        'following_url': 'https://api.github.com/users/Brijeshid/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Brijeshid/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Brijeshid/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Brijeshid/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Brijeshid/orgs',
#        'repos_url': 'https://api.github.com/users/Brijeshid/repos',
#        'events_url': 'https://api.github.com/users/Brijeshid/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Brijeshid/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Brijeshid/gamesjunglee',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Brijeshid/gamesjunglee',
#       'forks_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/forks',
#       'keys_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/teams',
#       'hooks_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/events',
#       'assignees_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/tags',
#       'blobs_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/languages',
#       'stargazers_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/subscription',
#       'commits_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/merges',
#       'archive_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/downloads',
#       'issues_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Brijeshid/gamesjunglee/deployments',
#       'created_at': '2023-01-29T11:59:02Z',
#       'updated_at': '2023-02-08T07:51:35Z',
#       'pushed_at': '2023-04-26T09:31:42Z',
#       'git_url': 'git://github.com/Brijeshid/gamesjunglee.git',
#       'ssh_url': 'git@github.com:Brijeshid/gamesjunglee.git',
#       'clone_url': 'https://github.com/Brijeshid/gamesjunglee.git',
#       'svn_url': 'https://github.com/Brijeshid/gamesjunglee',
#       'homepage': 'https://gamesjunglee-new.vercel.app',
#       'size': 5591,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/21'},
#      'html': {'href': 'https://github.com/Brijeshid/gamesjunglee/pull/21'},
#      'issue': {'href': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/21'},
#      'comments': {'href': 'https://api.github.com/repos/Brijeshid/gamesjunglee/issues/21/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/21/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Brijeshid/gamesjunglee/pulls/21/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Brijeshid/gamesjunglee/statuses/46df39757fdc288624e69749377cde1577af27f3'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'Brijeshid',
#      'id': 117505462,
#      'node_id': 'U_kgDOBwD9tg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/117505462?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Brijeshid',
#      'html_url': 'https://github.com/Brijeshid',
#      'followers_url': 'https://api.github.com/users/Brijeshid/followers',
#      'following_url': 'https://api.github.com/users/Brijeshid/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Brijeshid/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Brijeshid/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Brijeshid/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Brijeshid/orgs',
#      'repos_url': 'https://api.github.com/users/Brijeshid/repos',
#      'events_url': 'https://api.github.com/users/Brijeshid/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Brijeshid/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 128,
#     'deletions': 87,
#     'changed_files': 4}},
# ...
#   'repo': {'id': 632633204,
#    'name': 'damir-kovac/Tic-tac-toe',
#    'url': 'https://api.github.com/repos/damir-kovac/Tic-tac-toe'},
#   'payload': {'repository_id': 632633204,
#    'push_id': 13430594546,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b54272fb005f472a2fe86bc1546b3d1ce5cbb5bf',
#    'before': '758e1d56d1a8b203357be341c9f6182ad6947c2d',
#    'commits': [{'sha': 'b54272fb005f472a2fe86bc1546b3d1ce5cbb5bf',
#      'author': {'email': 'kovac.damir@outlook.com', 'name': 'Damir'},
#      'message': 'Board with handled',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/damir-kovac/Tic-tac-toe/commits/b54272fb005f472a2fe86bc1546b3d1ce5cbb5bf'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091657',
#   'type': 'PushEvent',
#   'actor': {'id': 45359738,
#    'login': 'GeraldDizon',
#    'display_login': 'GeraldDizon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GeraldDizon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45359738?'},
#   'repo': {'id': 627254595,
#    'name': 'GeraldDizon/portfolio2023',
#    'url': 'https://api.github.com/repos/GeraldDizon/portfolio2023'},
#   'payload': {'repository_id': 627254595,
#    'push_id': 13430594561,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8ea5f643279b4adcaa9bf29119dd12a2d537d234',
#    'before': '6f808b72e2ce74220272e54876b19aede068182e',
#    'commits': [{'sha': '8ea5f643279b4adcaa9bf29119dd12a2d537d234',
#      'author': {'email': 'geralddizon84@yahoo.com', 'name': 'Your Name'},
#      'message': 'Fix Images',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GeraldDizon/portfolio2023/commits/8ea5f643279b4adcaa9bf29119dd12a2d537d234'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091638',
#   'type': 'DeleteEvent',
#   'actor': {'id': 1448057,
#    'login': 'MyIgel',
#    'display_login': 'MyIgel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MyIgel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1448057?'},
#   'repo': {'id': 3996236,
#    'name': 'engelsystem/engelsystem',
#    'url': 'https://api.github.com/repos/engelsystem/engelsystem'},
#   'payload': {'ref': 'dependabot/composer/nyholm/psr7-1.6.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z',
#   'org': {'id': 8684380,
#    'login': 'engelsystem',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/engelsystem',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8684380?'}},
#  {'id': '28671091616',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 345038471,
#    'name': 'isjerryxiao/rushed_dn42_map',
#    'url': 'https://api.github.com/repos/isjerryxiao/rushed_dn42_map'},
#   'payload': {'repository_id': 345038471,
#    'push_id': 13430594551,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a9ce7cb93533e5d0e28e00f5a929c2d029d7d670',
#    'before': 'ab8042aaddc5188b2831a8cefa311fc0a3028068',
#    'commits': [{'sha': 'a9ce7cb93533e5d0e28e00f5a929c2d029d7d670',
#      'author': {'email': 'bot@github.com', 'name': 'bot'},
#      'message': '[skip ci] keepalive at 2023-04-26T09:31:41Z',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/isjerryxiao/rushed_dn42_map/commits/a9ce7cb93533e5d0e28e00f5a929c2d029d7d670'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091625',
#   'type': 'PushEvent',
#   'actor': {'id': 11835852,
#    'login': 'msconfig',
#    'display_login': 'msconfig',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/msconfig',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835852?'},
#   'repo': {'id': 252563659,
#    'name': 'msconfig/msconfig.github.io',
#    'url': 'https://api.github.com/repos/msconfig/msconfig.github.io'},
#   'payload': {'repository_id': 252563659,
#    'push_id': 13430594583,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2555f5ec63ef408985c74aeb58459403b88ce132',
#    'before': 'f62b5cf18dbe8b11404645d64b7fa4e2ca000427',
#    'commits': [{'sha': '2555f5ec63ef408985c74aeb58459403b88ce132',
#      'author': {'email': 'msconfig@users.noreply.github.com',
#       'name': 'msconfig'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/msconfig/msconfig.github.io/commits/2555f5ec63ef408985c74aeb58459403b88ce132'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091634',
#   'type': 'CreateEvent',
#   'actor': {'id': 125978974,
#    'login': 'yusrinelson',
#    'display_login': 'yusrinelson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yusrinelson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125978974?'},
#   'repo': {'id': 632862343,
#    'name': 'yusrinelson/-YUSNEL019_FTC2301_Group-Naeem_YusriNelson_ITW17',
#    'url': 'https://api.github.com/repos/yusrinelson/-YUSNEL019_FTC2301_Group-Naeem_YusriNelson_ITW17'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091647',
#   'type': 'IssuesEvent',
#   'actor': {'id': 14877573,
#    'login': 'kli017',
#    'display_login': 'kli017',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kli017',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14877573?'},
#   'repo': {'id': 38900806,
#    'name': 'aleju/imgaug',
#    'url': 'https://api.github.com/repos/aleju/imgaug'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/aleju/imgaug/issues/73',
#     'repository_url': 'https://api.github.com/repos/aleju/imgaug',
#     'labels_url': 'https://api.github.com/repos/aleju/imgaug/issues/73/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/aleju/imgaug/issues/73/comments',
#     'events_url': 'https://api.github.com/repos/aleju/imgaug/issues/73/events',
#     'html_url': 'https://github.com/aleju/imgaug/issues/73',
#     'id': 267961470,
#     'node_id': 'MDU6SXNzdWUyNjc5NjE0NzA=',
#     'number': 73,
#     'title': 'image size changed',
#     'user': {'login': 'kli017',
#      'id': 14877573,
#      'node_id': 'MDQ6VXNlcjE0ODc3NTcz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/14877573?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kli017',
#      'html_url': 'https://github.com/kli017',
#      'followers_url': 'https://api.github.com/users/kli017/followers',
#      'following_url': 'https://api.github.com/users/kli017/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kli017/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kli017/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kli017/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kli017/orgs',
#      'repos_url': 'https://api.github.com/users/kli017/repos',
#      'events_url': 'https://api.github.com/users/kli017/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kli017/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2017-10-24T09:33:43Z',
#     'updated_at': '2023-04-26T09:31:42Z',
#     'closed_at': '2023-04-26T09:31:42Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': "Hello I am using imgaug do image augmentation on my image set and my code is like this\r\n`for char in path:\r\n    subdir = root+'/'+ data +'/'+char\r\n    childpath = os.listdir(subdir)\r\n    for child in childpath:\r\n        subpath = data+'/' +char + '/'+child\r\n        d = ' %s' %(i)\r\n        t = subpath + d\r\n        img_pil = Image.open(subpath)\r\n        images = np.array(img_pil)\r\n        seq = iaa.Sequential([iaa.GaussianBlur((0, 0.5)),\r\n                              iaa.ContrastNormalization((0.75, 1.5)),\r\n\t\t\t\t\t\t\t  iaa.AverageBlur(k=(2, 7))\r\n\t\t])\r\n\t\t\r\n        images_aug = seq.augment_images([images])[0]\r\n        new_img = np.array(images_aug)\r\n        scipy.misc.imsave(subpath +'au.jpg', new_img)\r\n        print new_img.shape\r\n`\r\nmy input image is 32by32by3 but the size of output image became 33by32by3??\r\nanyone know what happened here?",
#     'reactions': {'url': 'https://api.github.com/repos/aleju/imgaug/issues/73/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/aleju/imgaug/issues/73/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'}},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091590',
#   'type': 'PushEvent',
#   'actor': {'id': 92167642,
#    'login': 'gitbook-com[bot]',
#    'display_login': 'gitbook-com',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gitbook-com[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92167642?'},
#   'repo': {'id': 249234386,
#    'name': 'steveseguin/vdo.ninja',
#    'url': 'https://api.github.com/repos/steveseguin/vdo.ninja'},
#   'payload': {'repository_id': 249234386,
#    'push_id': 13430594503,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gitbook',
#    'head': '4813b6b1811e11134cdc439009eb2707a64d416b',
#    'before': '87b90602a1825dfa9663adfc4ae3f67b7d417027',
#    'commits': [{'sha': '4813b6b1811e11134cdc439009eb2707a64d416b',
#      'author': {'email': 'jk14@uedv.org', 'name': 'jk14'},
#      'message': 'GITBOOK-1610: change request with no subject merged in GitBook',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/steveseguin/vdo.ninja/commits/4813b6b1811e11134cdc439009eb2707a64d416b'}]},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z'},
#  {'id': '28671091613',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 112474158,
#    'login': 'onlydust-contributor',
#    'display_login': 'onlydust-contributor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onlydust-contributor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112474158?'},
#   'repo': {'id': 602953043,
#    'name': 'od-mocks/cool-repo-A',
#    'url': 'https://api.github.com/repos/od-mocks/cool-repo-A'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/2',
#     'repository_url': 'https://api.github.com/repos/od-mocks/cool-repo-A',
#     'labels_url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/2/comments',
#     'events_url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/2/events',
#     'html_url': 'https://github.com/od-mocks/cool-repo-A/pull/2',
#     'id': 1593703299,
#     'node_id': 'PR_kwDOI_BVU85KcP7V',
#     'number': 2,
#     'title': 'Another update README.md',
#     'user': {'login': 'oscarwroche',
#      'id': 21149076,
#      'node_id': 'MDQ6VXNlcjIxMTQ5MDc2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/21149076?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/oscarwroche',
#      'html_url': 'https://github.com/oscarwroche',
#      'followers_url': 'https://api.github.com/users/oscarwroche/followers',
#      'following_url': 'https://api.github.com/users/oscarwroche/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/oscarwroche/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/oscarwroche/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/oscarwroche/subscriptions',
#      'organizations_url': 'https://api.github.com/users/oscarwroche/orgs',
#      'repos_url': 'https://api.github.com/users/oscarwroche/repos',
#      'events_url': 'https://api.github.com/users/oscarwroche/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/oscarwroche/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 964,
#     'created_at': '2023-02-21T15:43:47Z',
#     'updated_at': '2023-04-26T09:31:42Z',
#     'closed_at': '2023-04-12T12:29:06Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/od-mocks/cool-repo-A/pulls/2',
#      'html_url': 'https://github.com/od-mocks/cool-repo-A/pull/2',
#      'diff_url': 'https://github.com/od-mocks/cool-repo-A/pull/2.diff',
#      'patch_url': 'https://github.com/od-mocks/cool-repo-A/pull/2.patch',
#      'merged_at': None},
#     'body': '# DO NOT MERGE, CLOSE OR DELETE THIS PR\r\n\r\nOr some e2e tests might fail...',
#     'reactions': {'url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/2/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/2/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/comments/1523094605',
#     'html_url': 'https://github.com/od-mocks/cool-repo-A/pull/2#issuecomment-1523094605',
#     'issue_url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/2',
#     'id': 1523094605,
#     'node_id': 'IC_kwDOI_BVU85ayJRN',
#     'user': {'login': 'onlydust-contributor',
#      'id': 112474158,
#      'node_id': 'U_kgDOBrQ4Lg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/112474158?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/onlydust-contributor',
#      'html_url': 'https://github.com/onlydust-contributor',
#      'followers_url': 'https://api.github.com/users/onlydust-contributor/followers',
#      'following_url': 'https://api.github.com/users/onlydust-contributor/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/onlydust-contributor/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/onlydust-contributor/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/onlydust-contributor/subscriptions',
#      'organizations_url': 'https://api.github.com/users/onlydust-contributor/orgs',
#      'repos_url': 'https://api.github.com/users/onlydust-contributor/repos',
#      'events_url': 'https://api.github.com/users/onlydust-contributor/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/onlydust-contributor/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-04-26T09:31:42Z',
#     'updated_at': '2023-04-26T09:31:42Z',
#     'author_association': 'NONE',
#     'body': 'This item belongs to payment request #93E699 on [OnlyDust](https://www.onlydust.xyz/):\n* from [tokio-rs](https://www.onlydust.xyz/) to [ofux](https://www.onlydust.xyz/)\n* 2 items included\n* $100 for 2 hours of work',
#     'reactions': {'url': 'https://api.github.com/repos/od-mocks/cool-repo-A/issues/comments/1523094605/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-04-26T09:31:43Z',
#   'org': {'id': 121887739,
#    'login': 'od-mocks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/od-mocks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/121887739?'}}]

# %%
pd.DataFrame(response.json())

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-now.json'

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '-49.6654', 'longitude': '156.2809'},
#  'message': 'success',
#  'timestamp': 1682502207}

# %% [markdown]
# {'latitude': '-51.1927', 'longitude': '145.6277'}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"longitude": 52.53370520371973, "latitude": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code

# %%
response.url

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code

# %%
response.json()

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)

# %%
pd.to_datetime(1637772367, unit="s")
